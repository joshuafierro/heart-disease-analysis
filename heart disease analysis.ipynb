# %% [markdown]
# # Heart Disease Analysis
# ###### data provided by UCI

# %%
import numpy as np
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
from pylab import rcParams
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import mean_absolute_error
import urllib
from sklearn import preprocessing
from sklearn.metrics import classification_report

# %%
dims = (6,6)
fig, ax = plt.subplots(figsize=dims)
sns.set_style('whitegrid')
sns.set_color_codes("colorblind")
# %matplotlib inline

# %%
heart_data = pd.read_csv("heart.csv")
heart_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
# age         303 non-null int64
# sex         303 non-null int64
# cp          303 non-null int64
# trestbps    303 non-null int64
# chol        303 non-null int64
# fbs         303 non-null int64
# restecg     303 non-null int64
# thalach     303 non-null int64
# exang       303 non-null int64
# oldpeak     303 non-null float64
# slope       303 non-null int64
# ca          303 non-null int64
# thal        303 non-null int64
# target      303 non-null int64
# dtypes: float64(1), int64(13)
# memory usage: 33.2 KB

# %%
heart_data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %% [markdown]
# Attribute Information:
# > 1. age
# > 2. sex (1 = male; 0 = female)
# > 3. cp = chest pain type (4 values)
# > 4. trestbps = resting blood pressure (in mm Hg on admission to the hospital)
# > 5. chol = serum cholestoral in mg/dl
# > 6. fbs = fasting blood sugar > 120 mg/dl (1 = true; 0 = false)
# > 7. restecg = resting electrocardiographic results (values 0,1,2)
# > 8. thalach = maximum heart rate achieved
# > 9. exang = exercise induced angina (1 = yes; 0 = no)
# > 10. oldpeak = ST depression induced by exercise relative to rest
# > 11. the slope of the peak exercise ST segment
# > 12. ca = number of major vessels (0-3) colored by flourosopy
# > 13. thal: 3 = normal; 6 = fixed defect; 7 = reversable defect

# %%
# looking for correlations
heart_data.corr()
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.098447 -0.068653  0.279351  0.213678  0.121308
# sex      -0.098447  1.000000 -0.049353 -0.056769 -0.197912  0.045032
# cp       -0.068653 -0.049353  1.000000  0.047608 -0.076904  0.094444
# trestbps  0.279351 -0.056769  0.047608  1.000000  0.123174  0.177531
# chol      0.213678 -0.197912 -0.076904  0.123174  1.000000  0.013294
# fbs       0.121308  0.045032  0.094444  0.177531  0.013294  1.000000
# restecg  -0.116211 -0.058196  0.044421 -0.114103 -0.151040 -0.084189
# thalach  -0.398522 -0.044020  0.295762 -0.046698 -0.009940 -0.008567
# exang     0.096801  0.141664 -0.394280  0.067616  0.067023  0.025665
# oldpeak   0.210013  0.096093 -0.149230  0.193216  0.053952  0.005747
# slope    -0.168814 -0.030711  0.119717 -0.121475 -0.004038 -0.059894
# ca        0.276326  0.118261 -0.181053  0.101389  0.070511  0.137979
# thal      0.068001  0.210041 -0.161736  0.062210  0.098803 -0.032019
# ...

# %%
#plt.subplots(figsize=(20,15))
# making a heatmap of the correlations to make it easier for analysis
#sns.heatmap(heart_data.corr(), cmap="YlGnBu", annot=True)

# %%
heart_corrs = heart_data.corr()
heart_corrs >0.2 #there is no correlation greater than 0.3 which denotes a weak uphill (positive) linear relationship
# Out:
#             age    sex     cp  trestbps   chol    fbs  restecg  thalach  \
# age        True  False  False      True   True  False    False    False
# sex       False   True  False     False  False  False    False    False
# cp        False  False   True     False  False  False    False     True
# trestbps   True  False  False      True  False  False    False    False
# chol       True  False  False     False   True  False    False    False
# fbs       False  False  False     False  False   True    False    False
# restecg   False  False  False     False  False  False     True    False
# thalach   False  False   True     False  False  False    False     True
# exang     False  False  False     False  False  False    False    False
# oldpeak    True  False  False     False  False  False    False    False
# slope     False  False  False     False  False  False    False     True
# ca         True  False  False     False  False  False    False    False
# ...

# %%
# narrowing down the features
features = ['age', 'trestbps', 'chol', 'oldpeak', 'ca', 'thal', 'cp', 'target', 'exang', 'slope', 'thalach']
heart_corrs_revised = heart_data[features].corr()
plt.subplots(figsize=(20,15))
sns.heatmap(heart_corrs_revised, cmap='YlGnBu', annot=True)

# %%
# now that we narrowed the features down a bit I was able to notice pockets of strong correlations between features.
feature_set1 = ['age', 'trestbps', 'chol', 'oldpeak', 'ca', 'thal']
feature_set2 = ['target', 'cp', 'slope', 'thalach']

# %%
plt.subplots(figsize=(15,5))
plt.subplot(1,2,1)
heart_corrs_set1 = heart_data[feature_set1].corr()
sns.heatmap(heart_corrs_set1, annot=True)

plt.subplot(1,2,2)
heart_corrs_set2 = heart_data[feature_set2].corr()
sns.heatmap(heart_corrs_set2, annot=True)

# %% [markdown]
# <p>Here we are seeing a decent correlation between chest pain when maximum heart rate is achieved</p>

# %%
#scatter plot showing resting bp and maximum heart rate achieved
sns.scatterplot(data=heart_data[['trestbps', 'thalach']])

# %%
plt.subplots(figsize=(10,5))
#age kde
plt.subplot(1,2,1)
age_kde_plot = sns.kdeplot(data=heart_data['age'], shade=True)
age_kde_plot.set_title('Age KDE')


plt.subplot(1,2,2)
#distribution of sex and age
age_sex_plot = sns.barplot(x=heart_data.sex, y=heart_data.age)
age_sex_plot.set(xticklabels=["Female", "Male"])
age_sex_plot.set_title('Age vs Sex')
# Out:
# Text(0.5, 1.0, 'Age vs Sex')
